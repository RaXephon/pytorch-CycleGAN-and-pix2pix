# %%
# !git clone https://github.com/RaXephon/pytorch-CycleGAN-and-pix2pix.git
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 2243 (delta 8), reused 12 (delta 4), pack-reused 2226
# Receiving objects: 100% (2243/2243), 8.05 MiB | 10.55 MiB/s, done.
# Resolving deltas: 100% (1448/1448), done.

# %%
import os
os.chdir('..')

# %%
# !ls
# Out:
# checkpoints  docs	      LICENSE  pix2pix.ipynb	 scripts   util
# data	     environment.yml  models   README.md	 test.py
# datasets     imgs	      options  requirements.txt  train.py

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 686kB 23.4MB/s
# ...
#      |████████████████████████████████| 204kB 45.6MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655250 sha256=f150c69d0f6e9f47a30336c2fe417540b7c3d9bcddcfdcfd09ecdd0b004ab516
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5712 sha256=f643ff3ec33b6fa4f02aa517ac3b3d09330afe812064bfccb74a54b8546bc236
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...

# %%
## The following command downloads the dataset from Google Drive
## Link: https://docs.google.com/uc?export=download&confirm=bBat&id=14CkA9OldSeL5dgzyzT6jRfT3I4jpvWHD

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=14CkA9OldSeL5dgzyzT6jRfT3I4jpvWHD' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=14CkA9OldSeL5dgzyzT6jRfT3I4jpvWHD" -O overexposed && rm -rf /tmp/cookies.txt
# Out:
# --2020-05-03 19:37:51--  https://docs.google.com/uc?export=download&confirm=bBat&id=14CkA9OldSeL5dgzyzT6jRfT3I4jpvWHD
# Resolving docs.google.com (docs.google.com)... 209.85.145.113, 209.85.145.100, 209.85.145.102, ...
# Connecting to docs.google.com (docs.google.com)|209.85.145.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-cc-docs.googleusercontent.com/docs/securesc/3q5hdaaq50efamu2uo3ofiabr150nbbq/gtln2ao134a680immgjmltmt4cncs13p/1588534650000/06238626292003456861/13334044522866203714Z/14CkA9OldSeL5dgzyzT6jRfT3I4jpvWHD?e=download [following]
# --2020-05-03 19:37:52--  https://doc-0g-cc-docs.googleusercontent.com/docs/securesc/3q5hdaaq50efamu2uo3ofiabr150nbbq/gtln2ao134a680immgjmltmt4cncs13p/1588534650000/06238626292003456861/13334044522866203714Z/14CkA9OldSeL5dgzyzT6jRfT3I4jpvWHD?e=download
# ...

# %%
# !bash ./datasets/download_pix2pix_dataset.sh facades

# %%
# !python train.py --dataroot ./datasets/overexposed/dataset  --model pix2pix --direction AtoB --lr 0.004 --lr_policy "cosine" --n_epochs 20 --gpu_id 0
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/overexposed/dataset	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                 lambda_L1: 100.0
# ...

# %%
# for f in os.listdir("datasets/overexposed/dataset/test"):
#   if int(f.split(".")[0]) > 
# !python3 test.py --dataroot ./datasets/overexposed/dataset/ --direction AtoB --model pix2pix --name experiment_name
# !ls checkpoints/experiment_name/
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/overexposed/dataset/	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: experiment_name
#                       ndf: 64
# ...

# %%
# Out:
# pytorch-CycleGAN-and-pix2pix  tutorials
